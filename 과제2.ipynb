# %%
word1 = 'apple'
word2 = 'banana'
vowels = "aeiou"
count = 0
for char in word1:
    if char in vowels:
        count+= 1
print(count)

count =0

for char in word2:
    if char in vowels:
        count+= 1
print(count)
# Out:
# 2
# 3

# %%
n = 5
m = 9
print(('*' * n + '\n') * m)
# Out:
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****
# *****

# %%
my_list = [4,2,1,3]
new_list1 = sorted(my_list)
print('원본: ', my_list)
print('반환: ', new_list1)

new_list2 = my_list.sort()
print('원본: ', my_list)
print('반환: ', new_list2)
# Out:
# 원본:  [4, 2, 1, 3]
# 반환:  [1, 2, 3, 4]
# 원본:  [1, 2, 3, 4]
# 반환:  None
